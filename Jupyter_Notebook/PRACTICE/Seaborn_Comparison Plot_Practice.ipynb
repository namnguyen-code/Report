# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
mpl.rcParams.update({'figure.facecolor':'white',
                     'font.size':14,
                     'xtick.labelsize':12,
                     'ytick.labelsize':12})

# %%
df = pd.read_csv(filepath_or_buffer=r'C:\Users\admin\Desktop\Data Science\Course-2021\05-Seaborn\StudentsPerformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.jointplot(data=df, x='math score', y='reading score')

# %%
sns.jointplot(data=df, x='math score', y='reading score', kind='hex')

# %%
sns.jointplot(data=df, x='math score', y='reading score', alpha=0.2)

# %%
sns.jointplot(data=df, x='math score', y='reading score', kind='hist', palette='PuBu')

# %%
sns.jointplot(data=df, x='math score', y='reading score', kind='kde', palette='PuBu')

# %%
sns.jointplot(data=df, x='math score', y='reading score', kind='kde', palette='PuBu', shade=True)

# %%
sns.jointplot(data=df, x='math score', y='reading score', hue='gender')

# %%
sns.pairplot(data=df)

# %%
sns.pairplot(data=df, hue='gender')

# %%
sns.pairplot(data=df, hue='gender', diag_kind='hist')

# %%
sns.pairplot(data=df, hue='gender', corner=True)
