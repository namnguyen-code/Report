# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
mpl.rcParams.update({'figure.facecolor':'white',
                     'font.size': 14,
                     'xtick.labelsize': 12,
                     'ytick.labelsize': 12})

# %%
df = pd.read_csv(filepath_or_buffer=r'C:\Users\admin\Desktop\Data Science\Course-2021\05-Seaborn\country_table.csv')

# %%
df.head()
# Out:
#                          Countries  Birth rate  Mortality rate  \
# 0                           AFRICA      32.577           7.837
# 1                             ASIA      15.796           7.030
# 2                           EUROPE      10.118          11.163
# 3  LATIN AMERICA AND THE CARIBBEAN      15.886           6.444
# 4                 NORTHERN AMERICA      11.780           8.833
#
#    Life expectancy  Infant mortality rate  Growth rate
# 0           63.472                 44.215        24.40
# 1           73.787                 23.185         8.44
# 2           78.740                  3.750         0.38
# 3           75.649                 14.570         8.89
# 4           79.269                  5.563         6.11

# %%
df = df.set_index("Countries")

# %%
sns.heatmap(data=df)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
sns.heatmap(df.drop('Life expectancy', axis=1))
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
df.drop('Life expectancy', axis=1)
# Out:
#                                  Birth rate  Mortality rate  \
# Countries
# AFRICA                               32.577           7.837
# ASIA                                 15.796           7.030
# EUROPE                               10.118          11.163
# LATIN AMERICA AND THE CARIBBEAN      15.886           6.444
# NORTHERN AMERICA                     11.780           8.833
# OCEANIA                              16.235           6.788
# WORLD                                17.963           7.601
#
#                                  Infant mortality rate  Growth rate
# Countries
# AFRICA                                          44.215        24.40
# ASIA                                            23.185         8.44
# EUROPE                                           3.750         0.38
# LATIN AMERICA AND THE CARIBBEAN                 14.570         8.89
# NORTHERN AMERICA                                 5.563         6.11
# ...

# %%
sns.heatmap(data=df.drop('Life expectancy', axis=1), linewidth=0.5)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
plt.figure(figsize=(16,9), dpi=300)
sns.heatmap(data=df.drop('Life expectancy', axis=1), linewidth=0.5, annot=True)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
plt.figure(figsize=(16,9), dpi=300)
sns.heatmap(data=df.drop('Life expectancy', axis=1), linewidth=0.5, annot=True, cmap='viridis')
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
sns.heatmap(data=df.drop('Life expectancy', axis=1),  linewidth=0.5, annot=True, cmap='viridis', center=40)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
sns.clustermap(data=df.drop('Life expectancy', axis=1), linewidth=0.5, annot=True, cmap='viridis')

# %%
sns.clustermap(data=np.transpose(df.drop('Life expectancy', axis=1)), linewidth=0.5, annot=True, cmap='viridis', col_cluster=False)
